# %%
from matplotlib import pyplot as plt
import imagereader as imagereader

# %%
# %%capture
imagereader.extract_racfile('./rac-files/','Payload_RT_20190629-140042_20190629-142214.rac')

# %%
image, metadata = imagereader.read_MATS_image('./Payload_RT_20190629-140042_20190629-142214/IMAGES/channel1_image_1')

# %%
plt.pcolor(image)

# %%
metadata
# Out:
# {u'BC': [],
#  u'CCDSEL': [1],
#  u'EXPTS': [1245852210],
#  u'EXPTSS': [2313],
#  u'FBINOV': [0],
#  u'FRAME': [2],
#  u'GAIN': [0],
#  u'JPEGQ': [101],
#  u'LBLNK': [291],
#  u'NBC': [0],
#  u'NCBIN': [1],
#  u'NCOL': [2047],
#  u'NCSKIP': [0],
#  u'NFLUSH': [1023],
#  u'NRBIN': [1],
#  u'NROW': [511],
#  u'NRSKIP': [0],
#  u'SID_mnemonic': [u'CCD data channel 1'],
#  u'TBLNK': [297],
#  u'TEMP': [4023],
#  u'TEXPMS': [60000],
#  u'TIMING1': [5149],
#  u'TIMING2': [518],
#  u'TIMING3': [41987],
#  u'VERSION': [50],
#  u'WDW': [7],
#  u'WDWOV': [0],
#  u'ZERO': [115]}
